# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
file="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
olympic=pd.read_csv(file,skiprows=4)
olympic.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympic.axes
# Out:
# [RangeIndex(start=0, stop=29216, step=1),
#  Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#         'Event', 'Event_gender', 'Medal'],
#        dtype='object')]

# %%
olympic.shape
# Out:
# (29216, 10)

# %%
olympic.size
# Out:
# 292160

# %%
olympic.empty
# Out:
# False

# %%
empty_df=pd.DataFrame([])

# %%
empty_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
empty_df.empty
# Out:
# True

# %%
olympic.T
# Out:
#                        0                 1                           2      \
# City                  Athens            Athens                      Athens
# Edition                 1896              1896                        1896
# Sport               Aquatics          Aquatics                    Aquatics
# Discipline          Swimming          Swimming                    Swimming
# Athlete        HAJOS, Alfred  HERSCHMANN, Otto           DRIVAS, Dimitrios
# NOC                      HUN               AUT                         GRE
# Gender                   Men               Men                         Men
# Event         100m freestyle    100m freestyle  100m freestyle for sailors
# Event_gender               M                 M                           M
# Medal                   Gold            Silver                      Bronze
#
#                                    3                           4      \
# City                              Athens                      Athens
# ...

# %%
olympic.transpose()
# Out:
#                        0                 1                           2      \
# City                  Athens            Athens                      Athens
# Edition                 1896              1896                        1896
# Sport               Aquatics          Aquatics                    Aquatics
# Discipline          Swimming          Swimming                    Swimming
# Athlete        HAJOS, Alfred  HERSCHMANN, Otto           DRIVAS, Dimitrios
# NOC                      HUN               AUT                         GRE
# Gender                   Men               Men                         Men
# Event         100m freestyle    100m freestyle  100m freestyle for sailors
# Event_gender               M                 M                           M
# Medal                   Gold            Silver                      Bronze
#
#                                    3                           4      \
# City                              Athens                      Athens
# ...

# %%
olympic.count()
# Out:
# City            29216
# Edition         29216
# Sport           29216
# Discipline      29216
# Athlete         29216
# NOC             29216
# Gender          29216
# Event           29216
# Event_gender    29216
# Medal           29216
# dtype: int64

# %%
olympic.size
# Out:
# 292160

# %%
olympic.values
# Out:
# array([['Athens', 1896, 'Aquatics', ..., '100m freestyle', 'M', 'Gold'],
#        ['Athens', 1896, 'Aquatics', ..., '100m freestyle', 'M', 'Silver'],
#        ['Athens', 1896, 'Aquatics', ..., '100m freestyle for sailors',
#         'M', 'Bronze'],
#        ...,
#        ['Beijing', 2008, 'Wrestling', ..., '96 - 120kg', 'M', 'Bronze'],
#        ['Beijing', 2008, 'Wrestling', ..., '96 - 120kg', 'M', 'Gold'],
#        ['Beijing', 2008, 'Wrestling', ..., '96 - 120kg', 'M', 'Silver']],
#       dtype=object)

# %%
len(olympic)
# Out:
# 29216

# %%
# read csv
pd.read_csv()
# read excel
pd.read_excel()
# all sheet {sheet1:df1,sheet2:df2.......sheetn:dfn}
#read Json
pd.read_json()
#read html
pd.read_html()
# all table [df1 as table1,......dfn as table n ]

# %%
# read Sql Table from MySql

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection
import pandas as pd
mydb = connection.connect(host="localhost", database = 'data_science', user="root", passwd="edubridge@123",use_pure=True)
query = "Select * from books;"
result_dataFrame = pd.read_sql(query,mydb)
mydb.close()
# Out:
# C:\Users\karthick\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
result_dataFrame
# Out:
#    id         book_name    author_name date_created
# 0   1   THe Hunger Game  suznne collin   2008-09-14
# 1   2  Harry poter Game    J.K Rowling   1997-07-30
# 2   3         Divergent  Veronica Roth   2011-04-25

# %%
import mysql.connector as connection
import pandas as pd
mydb = connection.connect(host="localhost", database = 'data_science', user="root", passwd="edubridge@123")
query = "Select * from customer;"
customer_df = pd.read_sql(query,mydb)
mydb.close()
customer_df
# Out:
# C:\Users\karthick\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id   name          city  age
# 0   1   John      New York   35
# 1   2  David   Los Angeles   23
# 2   3  Chloe       Chicago   27
# 3   4  Emily       Houston   34
# 4   5  James  Philadelphia   31

# %% [markdown]
# ### Adding a new column to a DataFrame
# There are four ways to insert a new column in a DataFrame

# %%
std_age=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
std_age
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### 1.With the indexing operator, [ ]

# %%
std_age['class4']=[25,52]  # if class4 is already there , it will overwrite the value else it create new
std_age
# Out:
#    class 1  class 2  class 3  class4
# 0       22       24       20      25
# 1       40       50       45      52

# %%
std_age['class4']=[60,34]  
std_age
# Out:
#    class 1  class 2  class 3  class4
# 0       22       24       20      60
# 1       40       50       45      34

# %% [markdown]
# ### 2.Using the insert method

# %%
std_age.insert(1,"ClassB",[25,50])
std_age
# Out:
#    class 1  ClassB  class 2  class 3  class4
# 0       22      25       24       20      60
# 1       40      50       50       45      34

# %% [markdown]
# ### 3.Using the loc indexer

# %%
std_age.loc[:,"Class5"]=[100,100] ## if Column is exist it will overwrite the data else create new column
std_age
# Out:
#    class 1  ClassB  class 2  class 3  class4  class5  Class5
# 0       22      25       24       20      60      35     100
# 1       40      50       50       45      34      36     100

# %% [markdown]
# ### 4.Using the concat function

# %%
batchxy=pd.Series([45,50])
batchxy
pd.concat([std_age,batchxy],axis=1,ignore_index=True)
# Out:
#     0   1   2   3   4   5    6   7
# 0  22  25  24  20  60  35  100  45
# 1  40  50  50  45  34  36  100  50

# %% [markdown]
# ## Inserting rows in a DataFrame
# - There are two methods for adding rows in a DataFrame, either by using the append method or with the concat function.

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### 1.Using the append method

# %%
combined_ages=combined_ages.append({'class 1':35,'class 2':33,'class 3':21},ignore_index=True)
combined_ages
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_38196\321750320.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_ages=combined_ages.append({'class 1':35,'class 2':33,'class 3':21},ignore_index=True)
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45
# 2       35       33       21

# %% [markdown]
# ### 2.Using the pd.concat function

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
new_row=pd.DataFrame([{'class 1':32,'class 2':37,'class 3':41}])
new_row
# Out:
#    class 1  class 2  class 3
# 0       32       37       41

# %%
new_row2=pd.DataFrame([{'class 1':52,'class 2':67,'class 3':61,'class4':89}])
new_row2
# Out:
#    class 1  class 2  class 3  class4
# 0       52       67       61      89

# %%
pd.concat([combined_ages,new_row,new_row2],axis=0,ignore_index=True)
# Out:
#    class 1  class 2  class 3  class4
# 0       22       24       20     NaN
# 1       40       50       45     NaN
# 2       32       37       41     NaN
# 3       52       67       61    89.0

# %% [markdown]
# # concatenate Multiple file into one single file:

# %%
import pandas as pd
jan_file="https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv"
sale_jan=pd.read_csv(jan_file)
sale_jan.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sale_jan.shape
# Out:
# (9723, 6)

# %%
#Q1 data Data Analysis

# %%
months=['January','February','March']
Q1=[f'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_{month}_2019.csv' for month in months]

# %%
Q1
# Out:
# ['https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_February_2019.csv',
#  'https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_March_2019.csv']

# %%
import pandas as pd
Q1_sale=pd.concat([pd.read_csv(file) for file in Q1],axis=0,ignore_index=True)

# %%
Q1_sale
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 36980   176554  Lightning Charging Cable                1      14.95
# 36981   176555          27in FHD Monitor                1     149.99
# 36982   176556    AAA Batteries (4-pack)                3       2.99
# 36983   176557                    iPhone                1        700
# 36984   176557  Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# 0      01/22/19 21:25            944 Walnut St, Boston, MA 02215
# ...

# %%
Q1_sale.shape
# Out:
# (36985, 6)

# %%
Q1_sale
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 36980   176554  Lightning Charging Cable                1      14.95
# 36981   176555          27in FHD Monitor                1     149.99
# 36982   176556    AAA Batteries (4-pack)                3       2.99
# 36983   176557                    iPhone                1        700
# 36984   176557  Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# 0      01/22/19 21:25            944 Walnut St, Boston, MA 02215
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karthick\\EON-DA-2022-8161-8162'

# %%
os.getcwd()
# Out:
# 'I:\\EduBridge\\EON-DA Batch\\Sales_Data'

# %%
import os
path=r"I:\EduBridge\EON-DA Batch\Sales_Data"
os.chdir(path) 
all_data=pd.concat([pd.read_csv(file) for file in [file for file in os.listdir(path) if file.endswith(".csv")]],axis=0,ignore_index=True)
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
pd.concat(List_df,axis=0,ignore_index=True)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
import os
path=r"I:\EduBridge\EON-DA Batch\Sales_Data"
os.chdir(path) # change the current Working directory to path 
anual_data=pd.concat([pd.read_csv(file) for file in [file for file in os.listdir(path) if file.endswith('.csv')]],axis=0,ignore_index=True)
anual_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
os.chdir('C:\\Users\\karthick\\EON-DA-2022-8161-8162')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karthick\\EON-DA-2022-8161-8162'

# %% [markdown]
# ## Deleting columns from a DataFrame
# - Three methods can be used to delete a column from a DataFrame

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages['class 3']
# Out:
# 0    20
# 1    45
# Name: class 3, dtype: int64

# %% [markdown]
# ### 1. del operator

# %%
del combined_ages['class 3']

# %%
# after delete
combined_ages
# Out:
#    class 1  class 2
# 0       22       24
# 1       40       50

# %% [markdown]
# ### 2.Using the pop method

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages.pop('class 1') # in memory
# Out:
# 0    22
# 1    40
# Name: class 1, dtype: int64

# %%
combined_ages
# Out:
#    class 2  class 3
# 0       24       20
# 1       50       45

# %% [markdown]
# # 3.drop()  -  Drop specified labels from rows or columns

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages.drop(["class 1","class 3"],axis=1,inplace=False) #remove the second row, which has a row index of 3
# Out:
#    class 2
# 0       24
# 1       50

# %%
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages.drop(["class 1","class 3"],axis=1,inplace=True) # in memory

# %%
combined_ages
# Out:
#    class 2
# 0       24
# 1       50

# %% [markdown]
# ### Deleting a row from a DataFrame
# - There are two methods for removing rows from a DataFrame – either by using a Boolean selection or by using the drop method

# %%
combined_ages=pd.DataFrame({'class 1':[22,40],'class 2':[24,50],'class 3':[20,45]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages[~(combined_ages.values>40)]
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 0       22       24       20
# 0       22       24       20
# 1       40       50       45

# %% [markdown]
# ### Using the drop method

# %%
combined_ages=pd.DataFrame({'class 1':[22,40,90],'class 2':[24,50,67],'class 3':[20,45,67]})
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45
# 2       90       67       67

# %%
combined_ages.drop([0,2],axis=0,inplace=False)
# Out:
#    class 1  class 2  class 3
# 1       40       50       45

# %% [markdown]
# # Exercise problems:

# %% [raw]
# read the data from given url to DataFrame as sales_data
# https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv
#
# Q1.Rename The column name with valid format:
#     oldname:Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
#     newname:Order_ID,Product,Quantity_Ordered,Price_Each,Order_Date,Purchase_Address
#
# Q2.insert new column as order_price
# compute order_price =Price_Each*Quantity_Ordered
#
# Q3.Delete the column Purchase_Address
#
# Q4.insert new row data as  at last
# 100001,OnePhone,1,600, 01/22/19 21:25,600

# %%
# read CSV file to dataframe
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv"
sales_data=pd.read_csv(url)
sales_data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# cleaning the column name

# %%
sales_data.columns=sales_data.columns.str.replace(" ","_")

# %%
sales_data.columns
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'Purchase_Address'],
#       dtype='object')

# %%
sales_data.head()
# Out:
#   Order_ID                   Product Quantity_Ordered Price_Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order_Date                       Purchase_Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sales_data.iloc[-4:,:]
# Out:
#      Order_ID                 Product Quantity_Ordered Price_Each  \
# 9719   150498        27in FHD Monitor                1     149.99
# 9720   150499         ThinkPad Laptop                1     999.99
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9722   150501            Google Phone                1        600
#
#           Order_Date                     Purchase_Address
# 9719  01/10/19 22:58  403 7th St, San Francisco, CA 94016
# 9720  01/21/19 14:31      214 Main St, Portland, OR 97035
# 9721  01/15/19 14:21    810 2nd St, Los Angeles, CA 90001
# 9722  01/13/19 16:43       428 Cedar St, Boston, MA 02215

# %%
sales_data.tail(n=4)
# Out:
#      Order_ID                 Product Quantity_Ordered Price_Each  \
# 9719   150498        27in FHD Monitor                1     149.99
# 9720   150499         ThinkPad Laptop                1     999.99
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9722   150501            Google Phone                1        600
#
#           Order_Date                     Purchase_Address
# 9719  01/10/19 22:58  403 7th St, San Francisco, CA 94016
# 9720  01/21/19 14:31      214 Main St, Portland, OR 97035
# 9721  01/15/19 14:21    810 2nd St, Los Angeles, CA 90001
# 9722  01/13/19 16:43       428 Cedar St, Boston, MA 02215

# %%
sales_data.Product.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product'>

# %% [raw]
# # str methods on column data

# %%
newdf["Order_Date"].str.split(' ')
# Out:
# 0       [01/22/19, 21:25]
# 1       [01/28/19, 14:15]
# 2       [01/17/19, 13:33]
# 3       [01/05/19, 20:33]
# 4       [01/25/19, 11:59]
#               ...
# 9718    [01/26/19, 19:09]
# 9719    [01/10/19, 22:58]
# 9720    [01/21/19, 14:31]
# 9721    [01/15/19, 14:21]
# 9722    [01/13/19, 16:43]
# Name: Order_Date, Length: 9723, dtype: object

# %%
#for deleting  
newdf.drop('Purchase_Address', inplace=True, axis=1)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity_Ordered  9697 non-null   object
#  3   Price_Each        9697 non-null   object
#  4   Order_Date        9697 non-null   object
#  5   Purchase_Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
sales_data['Quantity_Ordered'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [235], in <cell line: 1>()
# ----> 1 sales_data['Quantity_Ordered'].astype('int')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# drop the NaN value
# first Find Where Nan value present  in your Dataset

# %%
sales_data.isna().sum()  # total 26 NaN records present in our data set
# Out:
# Order_ID            26
# Product             26
# Quantity_Ordered    26
# Price_Each          26
# Order_Date          26
# Purchase_Address    26
# dtype: int64

# %%
len(sales_data[sales_data.Price_Each.isna()])
# Out:
# 26

# %%
sales_data[sales_data.Price_Each.isna()]
# Out:
#      Order_ID Product Quantity_Ordered Price_Each Order_Date Purchase_Address
# 664       NaN     NaN              NaN        NaN        NaN              NaN
# 678       NaN     NaN              NaN        NaN        NaN              NaN
# 797       NaN     NaN              NaN        NaN        NaN              NaN
# 876       NaN     NaN              NaN        NaN        NaN              NaN
# 1299      NaN     NaN              NaN        NaN        NaN              NaN
# 1491      NaN     NaN              NaN        NaN        NaN              NaN
# 1699      NaN     NaN              NaN        NaN        NaN              NaN
# 3047      NaN     NaN              NaN        NaN        NaN              NaN
# 3082      NaN     NaN              NaN        NaN        NaN              NaN
# 3584      NaN     NaN              NaN        NaN        NaN              NaN
# 3659      NaN     NaN              NaN        NaN        NaN              NaN
# ...

# %%
# method1: clean NaN using Complement method
sales_data[~(sales_data.Price_Each.isna())]
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
#drop NaN value using dropna()
sales_data.dropna(axis=0,inplace=True)#Remove missing values.

# %%
sales_data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
9722-9697
# Out:
# 25

# %%
sales_data['Quantity_Ordered'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [264], in <cell line: 1>()
# ----> 1 sales_data['Quantity_Ordered'].astype('int')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
sales_data[sales_data['Quantity_Ordered']=='Quantity Ordered']
# Out:
#       Order_ID  Product  Quantity_Ordered  Price_Each  Order_Date  \
# 1073  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3115  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3247  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3612  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3623  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4901  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5593  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 6506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7544  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...

# %%
#method1 :remove Duplicate Data using complement

# %%
sales_data=sales_data[~(sales_data['Quantity_Ordered']=='Quantity Ordered')]

# %%
# create new columns

# %%
sales_data['Quantity_Ordered'].astype('int')
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 9718    1
# 9719    1
# 9720    1
# 9721    2
# 9722    1
# Name: Quantity_Ordered, Length: 9681, dtype: int32

# %%
Q2.insert new column as order_price  
compute order_price =Price_Each*Quantity_Ordered

# %%
sales_data['order_price']=sales_data['Quantity_Ordered'].astype('int')*sales_data['Price_Each'].astype('float')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_38196\2743652798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['order_price']=sales_data['Quantity_Ordered'].astype('int')*sales_data['Price_Each'].astype('float')

# %%
sales_data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date                       Purchase_Address  order_price
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215       700.00
# ...

# %%
Q3.Delete the column Purchase_Address

# %%
#method1:
del sales_data['Purchase_Address']
#method2: sales_data.drop(['Purchase_Address'],axis=1)

# %%
sales_data
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %%
Q4.insert new row data as  at last
100001,OnePhone,1,600, 01/22/19 21:25,600

# %%
d1=pd.DataFrame({"Order_ID":[100001],"Product":["OnePhone"],"Quantity_Ordered":[1],
                   "Price_Each":[600],"Order_Date":["01/22/19 21:25"],"order_price":[600]})

# %%
d1
# Out:
#    Order_ID   Product  Quantity_Ordered  Price_Each      Order_Date  \
# 0    100001  OnePhone                 1         600  01/22/19 21:25
#
#    order_price
# 0          600

# %%
pd.concat([sales_data,d1],axis=0,ignore_index=True)
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9677   150498          27in FHD Monitor                1     149.99
# 9678   150499           ThinkPad Laptop                1     999.99
# 9679   150500    AAA Batteries (4-pack)                2       2.99
# 9680   150501              Google Phone                1        600
# 9681   100001                  OnePhone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %%
df = sales_data.append(d1, ignore_index = True)
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_38196\3706209922.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = sales_data.append(d1, ignore_index = True)

# %%
df
# Out:
#      Order_ID                   Product Quantity_Ordered Price_Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9677   150498          27in FHD Monitor                1     149.99
# 9678   150499           ThinkPad Laptop                1     999.99
# 9679   150500    AAA Batteries (4-pack)                2       2.99
# 9680   150501              Google Phone                1        600
# 9681   100001                  OnePhone                1        600
#
#           Order_Date  order_price
# 0     01/22/19 21:25       700.00
# 1     01/28/19 14:15        14.95
# 2     01/17/19 13:33        23.98
# ...

# %% [markdown]
# # query the Data

# %%
sales_data[sales_data["order_price"]>600]    # select * from sales_data where order_price>600
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 0      141234              iPhone                1        700  01/22/19 21:25
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 96     141328     ThinkPad Laptop                1     999.99  01/06/19 23:18
# ...       ...                 ...              ...        ...             ...
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9707   150486              iPhone                1        700  01/26/19 15:52
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
#
#       order_price
# ...

# %%
sales_data[(sales_data["order_price"]>600)&~(sales_data["Product"]=='iPhone')] 
#select * from sales_data where order_price>600 and not product=iphone
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 96     141328     ThinkPad Laptop                1     999.99  01/06/19 23:18
# 128    141360  Macbook Pro Laptop                1       1700  01/17/19 21:00
# ...       ...                 ...              ...        ...             ...
# 9644   150425     ThinkPad Laptop                1     999.99  01/31/19 19:42
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
#
#       order_price
# ...

# %%
(sales_data["order_price"]>600)|(sales_data["Product"]=='iPhone')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9718    False
# 9719    False
# 9720     True
# 9721    False
# 9722    False
# Length: 9681, dtype: bool

# %%
sales_data[(sales_data["order_price"]>600)|(sales_data["Product"]=='iPhone')] 
#select * from sales_data where order_price>600 or product=iphone
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 0      141234              iPhone                1        700  01/22/19 21:25
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 96     141328     ThinkPad Laptop                1     999.99  01/06/19 23:18
# ...       ...                 ...              ...        ...             ...
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9707   150486              iPhone                1        700  01/26/19 15:52
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
#
#       order_price
# ...

# %% [markdown]
# ## Using the query method to retrieve data
# - While we combine multiple conditions as in the previous example, the readability of the code may suffer. The query method can be used in such cases.

# %%
sales_data.query("(order_price>600) and not(Product=='iPhone')")
#Query the columns of a DataFrame with a boolean expression.
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 96     141328     ThinkPad Laptop                1     999.99  01/06/19 23:18
# 128    141360  Macbook Pro Laptop                1       1700  01/17/19 21:00
# ...       ...                 ...              ...        ...             ...
# 9644   150425     ThinkPad Laptop                1     999.99  01/31/19 19:42
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
#
#       order_price
# ...

# %%
sales_data.query("(order_price>600) or (Product=='iPhone')")
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 0      141234              iPhone                1        700  01/22/19 21:25
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 96     141328     ThinkPad Laptop                1     999.99  01/06/19 23:18
# ...       ...                 ...              ...        ...             ...
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9699   150478     ThinkPad Laptop                1     999.99  01/30/19 20:05
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
# 9707   150486              iPhone                1        700  01/26/19 15:52
# 9720   150499     ThinkPad Laptop                1     999.99  01/21/19 14:31
#
#       order_price
# ...

# %%
sales_data.query("(order_price>1600)")
# Out:
#      Order_ID             Product Quantity_Ordered Price_Each      Order_Date  \
# 11     141245  Macbook Pro Laptop                1       1700  01/31/19 10:12
# 55     141288  Macbook Pro Laptop                1       1700  01/19/19 08:17
# 82     141314  Macbook Pro Laptop                1       1700  01/13/19 23:51
# 128    141360  Macbook Pro Laptop                1       1700  01/17/19 21:00
# 155    141385  Macbook Pro Laptop                1       1700  01/10/19 12:59
# ...       ...                 ...              ...        ...             ...
# 9529   150314  Macbook Pro Laptop                1       1700  01/27/19 09:52
# 9542   150325  Macbook Pro Laptop                1       1700  01/29/19 12:50
# 9577   150359  Macbook Pro Laptop                1       1700  01/13/19 22:28
# 9648   150429  Macbook Pro Laptop                1       1700  01/15/19 19:54
# 9701   150480  Macbook Pro Laptop                1       1700  01/27/19 16:00
#
#       order_price
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # Pandas Data operations

# %% [markdown]
# ### 1.Reading and writing data:
# - Pandas provides functions for reading in data from various formats, such as CSV, Excel, and SQL databases, and for writing data out to these formats.

# %%
import pandas as pd 
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
olympics=pd.read_csv(url,skiprows=4,index_col=['Edition','Sport'])
olympics.head()
# Out:
#                     City Discipline             Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics  Athens   Swimming       HAJOS, Alfred  HUN    Men
#         Aquatics  Athens   Swimming    HERSCHMANN, Otto  AUT    Men
#         Aquatics  Athens   Swimming   DRIVAS, Dimitrios  GRE    Men
#         Aquatics  Athens   Swimming  MALOKINIS, Ioannis  GRE    Men
#         Aquatics  Athens   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                                        Event Event_gender   Medal
# Edition Sport
# 1896    Aquatics              100m freestyle            M    Gold
#         Aquatics              100m freestyle            M  Silver
#         Aquatics  100m freestyle for sailors            M  Bronze
#         Aquatics  100m freestyle for sailors            M    Gold
#         Aquatics  100m freestyle for sailors            M  Silver

# %%
olympics.reset_index(inplace=True)

# %%
olympics
# Out:
#        Edition      Sport     City       Discipline               Athlete  \
# 0         1896   Aquatics   Athens         Swimming         HAJOS, Alfred
# 1         1896   Aquatics   Athens         Swimming      HERSCHMANN, Otto
# 2         1896   Aquatics   Athens         Swimming     DRIVAS, Dimitrios
# 3         1896   Aquatics   Athens         Swimming    MALOKINIS, Ioannis
# 4         1896   Aquatics   Athens         Swimming    CHASAPIS, Spiridon
# ...        ...        ...      ...              ...                   ...
# 29211     2008  Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko
# 29212     2008  Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213     2008  Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214     2008  Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain
# 29215     2008  Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
olympics.set_index(['Edition','Sport'],inplace=True)

# %%
olympics
# Out:
#                       City       Discipline               Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics    Athens         Swimming         HAJOS, Alfred  HUN    Men
#         Aquatics    Athens         Swimming      HERSCHMANN, Otto  AUT    Men
#         Aquatics    Athens         Swimming     DRIVAS, Dimitrios  GRE    Men
#         Aquatics    Athens         Swimming    MALOKINIS, Ioannis  GRE    Men
#         Aquatics    Athens         Swimming    CHASAPIS, Spiridon  GRE    Men
# ...                    ...              ...                   ...  ...    ...
# 2008    Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
#         Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
#         Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
#         Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
#         Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
# ...

# %%
olympics[olympics['Edition']==1896]
# Out:
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# ..      ...      ...            ...              ...
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
olympics.reset_index(inplace=True)

# %%
olympics.head()
# Out:
#    Edition     Sport    City Discipline             Athlete  NOC Gender  \
# 0     1896  Aquatics  Athens   Swimming       HAJOS, Alfred  HUN    Men
# 1     1896  Aquatics  Athens   Swimming    HERSCHMANN, Otto  AUT    Men
# 2     1896  Aquatics  Athens   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3     1896  Aquatics  Athens   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4     1896  Aquatics  Athens   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#writing data
olympics_1896=olympics[olympics['Edition']==1896]

# %%
olympics_1896.to_csv("olympics_1896",sep=',')

# %% [markdown]
# ### 2.Selecting and filtering data:
# - Pandas provides methods for selecting and filtering data based on certain criteria.

# %%
olympics['Edition']==1896
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Edition, Length: 29216, dtype: bool

# %%
olympics[olympics['Edition']==1896]
# Out:
#      Edition          Sport    City       Discipline  \
# 0       1896       Aquatics  Athens         Swimming
# 1       1896       Aquatics  Athens         Swimming
# 2       1896       Aquatics  Athens         Swimming
# 3       1896       Aquatics  Athens         Swimming
# 4       1896       Aquatics  Athens         Swimming
# ..       ...            ...     ...              ...
# 146     1896  Weightlifting  Athens    Weightlifting
# 147     1896  Weightlifting  Athens    Weightlifting
# 148     1896      Wrestling  Athens  Wrestling Gre-R
# 149     1896      Wrestling  Athens  Wrestling Gre-R
# 150     1896      Wrestling  Athens  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
 use the & , |, ~ operators to combine multiple criteria for selecting and filtering data:

# %%
olympics[(olympics['Edition']==1896)&(olympics['Medal']=='Gold') ]
# Out:
#      Edition          Sport    City       Discipline              Athlete  \
# 0       1896       Aquatics  Athens         Swimming        HAJOS, Alfred
# 3       1896       Aquatics  Athens         Swimming   MALOKINIS, Ioannis
# 6       1896       Aquatics  Athens         Swimming        HAJOS, Alfred
# 9       1896       Aquatics  Athens         Swimming        NEUMANN, Paul
# 13      1896      Athletics  Athens        Athletics        BURKE, Thomas
# ..       ...            ...     ...              ...                  ...
# 135     1896         Tennis  Athens           Tennis     TRAUN, Friedrich
# 140     1896         Tennis  Athens           Tennis         BOLAND, John
# 143     1896  Weightlifting  Athens    Weightlifting  ELLIOTT, Launceston
# 146     1896  Weightlifting  Athens    Weightlifting        JENSEN, Viggo
# 149     1896      Wrestling  Athens  Wrestling Gre-R       SCHUMANN, Carl
#
#      NOC Gender                        Event Event_gender Medal
# ...

# %%
olympics.query("(Edition==1896) and (Medal=='Gold')")[['Event','Event_gender','Medal']]
# Out:
#                            Event Event_gender Medal
# 0                 100m freestyle            M  Gold
# 3     100m freestyle for sailors            M  Gold
# 6                1200m freestyle            M  Gold
# 9                 400m freestyle            M  Gold
# 13                          100m            M  Gold
# ..                           ...          ...   ...
# 135                      doubles            M  Gold
# 140                      singles            M  Gold
# 143  heavyweight - one hand lift            M  Gold
# 146  heavyweight - two hand lift            M  Gold
# 149                   open event            M  Gold
#
# [64 rows x 3 columns]

# %% [markdown]
# ### 3.Grouping and aggregating data:
# - Pandas provides methods for grouping and aggregating data based on certain criteria.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aggregation is the process of summarizing a group of values into a single value.
# - 1.Split the data into smaller groups that are manageable and independent of each other. This is done using the groupby method in Pandas.
# - 2.Apply functions on each of these groups. We can apply any of the aggregation functions, including minimum, maximum, median, mean, sum, count, standard deviation, variance, and size.
# Each of these aggregate functions calculate the aggregate value of the entire group. Note that we can also write a customized aggregation function.
# - 3.Combine the results after applying functions to each group into a single combined object.

# %%
olympics.head()
# Out:
#    Edition     Sport    City Discipline             Athlete  NOC Gender  \
# 0     1896  Aquatics  Athens   Swimming       HAJOS, Alfred  HUN    Men
# 1     1896  Aquatics  Athens   Swimming    HERSCHMANN, Otto  AUT    Men
# 2     1896  Aquatics  Athens   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3     1896  Aquatics  Athens   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4     1896  Aquatics  Athens   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
gobj=olympics.groupby('Medal')

# %%
print(type(gobj))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
list(gobj)
# Out:
# [('Bronze',
#          Edition      Sport     City       Discipline                Athlete  \
#   2         1896   Aquatics   Athens         Swimming      DRIVAS, Dimitrios
#   5         1896   Aquatics   Athens         Swimming  CHOROPHAS, Efstathios
#   8         1896   Aquatics   Athens         Swimming  CHOROPHAS, Efstathios
#   11        1896  Athletics   Athens        Athletics          LANE, Francis
#   12        1896  Athletics   Athens        Athletics       SZOKOLYI, Alajos
#   ...        ...        ...      ...              ...                    ...
#   29205     2008  Wrestling  Beijing  Wrestling Gre-R          AVLUCA, Nazmi
#   29208     2008  Wrestling  Beijing  Wrestling Gre-R        MAMBETOV, Asset
#   29209     2008  Wrestling  Beijing  Wrestling Gre-R          WHEELER, Adam
#   29212     2008  Wrestling  Beijing  Wrestling Gre-R   MIZGAITIS, Mindaugas
#   29213     2008  Wrestling  Beijing  Wrestling Gre-R        PATRIKEEV, Yuri
#
# ...

# %%
for k,v in gobj:
    print(k)
# Out:
# Bronze
# Gold
# Silver

# %%
gobj.groups.keys()
# Out:
# dict_keys(['Bronze', 'Gold', 'Silver'])

# %%
gobj.nth(0)
# Out:
#         Edition     Sport    City Discipline            Athlete  NOC Gender  \
# Medal
# Bronze     1896  Aquatics  Athens   Swimming  DRIVAS, Dimitrios  GRE    Men
# Gold       1896  Aquatics  Athens   Swimming      HAJOS, Alfred  HUN    Men
# Silver     1896  Aquatics  Athens   Swimming   HERSCHMANN, Otto  AUT    Men
#
#                              Event Event_gender
# Medal
# Bronze  100m freestyle for sailors            M
# Gold                100m freestyle            M
# Silver              100m freestyle            M

# %%
gobj.ngroups
# Out:
# 3

# %%
gobj.size()
# Out:
# Medal
# Bronze    9689
# Gold      9850
# Silver    9677
# dtype: int64

# %%
#index of Group object
gobj.groups['Gold']
# Out:
# Int64Index([    0,     3,     6,     9,    13,    15,    18,    21,    24,
#                27,
#             ...
#             29179, 29183, 29187, 29191, 29195, 29199, 29203, 29206, 29210,
#             29214],
#            dtype='int64', length=9850)

# %%
gobj.get_group('Gold')
# Out:
#        Edition      Sport     City       Discipline              Athlete  NOC  \
# 0         1896   Aquatics   Athens         Swimming        HAJOS, Alfred  HUN
# 3         1896   Aquatics   Athens         Swimming   MALOKINIS, Ioannis  GRE
# 6         1896   Aquatics   Athens         Swimming        HAJOS, Alfred  HUN
# 9         1896   Aquatics   Athens         Swimming        NEUMANN, Paul  AUT
# 13        1896  Athletics   Athens        Athletics        BURKE, Thomas  USA
# ...        ...        ...      ...              ...                  ...  ...
# 29199     2008  Wrestling  Beijing  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203     2008  Wrestling  Beijing  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206     2008  Wrestling  Beijing  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210     2008  Wrestling  Beijing  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214     2008  Wrestling  Beijing  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
# aggregate

# %%
olympics.groupby('Medal').agg(['count'])
# Out:
#        Edition Sport  City Discipline Athlete   NOC Gender Event Event_gender
#          count count count      count   count count  count count        count
# Medal
# Bronze    9689  9689  9689       9689    9689  9689   9689  9689         9689
# Gold      9850  9850  9850       9850    9850  9850   9850  9850         9850
# Silver    9677  9677  9677       9677    9677  9677   9677  9677         9677

# %%
olympics.groupby('Medal').aggregate({"Edition":['min','max','count']})
# Out:
#        Edition
#            min   max count
# Medal
# Bronze    1896  2008  9689
# Gold      1896  2008  9850
# Silver    1896  2008  9677

# %% [markdown]
# # Example:

# %%
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
# Question 
Groupby continent  and apply sum as aggregation function on [cases,deaths ]

# %%
covid_data.groupby('continent').agg({'cases':'sum','deaths':'sum'})
# Out:
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %%
covid_data.groupby('continent')[['cases','deaths']].sum()
# Out:
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %% [markdown]
# ### 4.Sorting data:
# - Pandas provides methods for sorting data based on one or more columns.

# %%
#df.sort_values()

# %%
covid_data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0
# 3          AND     77006.0
# 4          AGO  30809762.0

# %%
covid_data.sort_values(['continent','country'],ascending=[True,False])
# Out:
#                                         country continent        date  day  \
# 205                                    Zimbabwe    Africa  2020-04-12   12
# 204                                      Zambia    Africa  2020-04-12   12
# 196                 United_Republic_of_Tanzania    Africa  2020-04-12   12
# 192                                      Uganda    Africa  2020-04-12   12
# 189                                     Tunisia    Africa  2020-04-12   12
# ..                                          ...       ...         ...  ...
# 80                                         Guam   Oceania  2020-04-12   12
# 70                             French_Polynesia   Oceania  2020-04-12   12
# 67                                         Fiji   Oceania  2020-04-12   12
# 10                                    Australia   Oceania  2020-04-12   12
# 37   Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
#
#      month  year  cases  deaths country_code  population
# ...

# %% [markdown]
# ### 5. Merging and joining data:
# - Pandas provides methods for merging and joining data from different sources.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],
                             'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],
                                      'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']})
#Join these two DataFrames just created vertically using the concat
periodic_table_extended
# Out:
#    Atomic Number   Element Symbol
# 0              8    Oxygen      O
# 1              9  Fluorine      F
# 2             10      Neon     Ne

# %%
pd.concat([periodic_table,periodic_table_extended],ignore_index=True, join= 'outer')
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B
# 5              8     Oxygen      O
# 6              9   Fluorine      F
# 7             10       Neon     Ne

# %%
pd.concat([periodic_table,periodic_table_extended],ignore_index=True, join= 'inner')
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B
# 5              8     Oxygen      O
# 6              9   Fluorine      F
# 7             10       Neon     Ne

# %% [markdown]
# ## Join method – index to index
# - The join method aligns two Pandas objects based on common index values.
# - That is,it looks for matching index values in both objects and then align them vertically.
# - The default type of join for this method is a left join.
# - Let us consider the following example where we join two objects.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbol':['H','He',
'Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']})
periodic_table_extended
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 periodic_table_extended=pd.DataFrame({'Atomic Number':[8,9,10],'Element':['Oxygen','Fluorine','Neon'],'Symbol':['O','F','Ne']})
#       2 periodic_table_extended
#
# NameError: name 'pd' is not defined

# %%
periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_right",how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_right",how='left')
#
# NameError: name 'periodic_table' is not defined

# %%
periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_reight",how='right')
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_reight  \
# 0                   1     Hydrogen           H                     8
# 1                   2       Helium          He                     9
# 2                   3      Lithium          Li                    10
#
#   Element_reight Symbol_reight
# 0         Oxygen             O
# 1       Fluorine             F
# 2           Neon            Ne

# %%
periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_reight",how='inner')
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_reight  \
# 0                   1     Hydrogen           H                     8
# 1                   2       Helium          He                     9
# 2                   3      Lithium          Li                    10
#
#   Element_reight Symbol_reight
# 0         Oxygen             O
# 1       Fluorine             F
# 2           Neon            Ne

# %%
periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_reight",how='outer')
# Out:
#    Atomic Number_left Element_left Symbol_left  Atomic Number_reight  \
# 0                   1     Hydrogen           H                   8.0
# 1                   2       Helium          He                   9.0
# 2                   3      Lithium          Li                  10.0
# 3                   4    Beryllium          Be                   NaN
# 4                   5        Boron           B                   NaN
#
#   Element_reight Symbol_reight
# 0         Oxygen             O
# 1       Fluorine             F
# 2           Neon            Ne
# 3            NaN           NaN
# 4            NaN           NaN

# %%
periodic_table.join(periodic_table_extended, lsuffix="_left",rsuffix="_reight",how='cross')
# Out:
#     Atomic Number_left Element_left Symbol_left  Atomic Number_reight  \
# 0                    1     Hydrogen           H                     8
# 1                    1     Hydrogen           H                     9
# 2                    1     Hydrogen           H                    10
# 3                    2       Helium          He                     8
# 4                    2       Helium          He                     9
# 5                    2       Helium          He                    10
# 6                    3      Lithium          Li                     8
# 7                    3      Lithium          Li                     9
# 8                    3      Lithium          Li                    10
# 9                    4    Beryllium          Be                     8
# 10                   4    Beryllium          Be                     9
# 11                   4    Beryllium          Be                    10
# ...

# %% [markdown]
# ### Merge method – SQL type join based on common columns
# - Like the join method, the merge method is also used to join objects horizontally.
# - It is used when we join two DataFrame objects with a common column name.
# - The maindifference between the join and merge methods is that
# - the join method combines the objects based on common index values, while the merge method combines the objects based on common column names.
# - Another difference is that the default join type in the merge method is an inner join,
# - while the join method performs a left join of the objects by default.
# - Let us look at how the merge method works with an example. The two DataFrame objects defined here have a column name that is common – Atomic Number.
# - This is a scenario where we can apply the merge method.

# %%
periodic_table=pd.DataFrame({'Atomic Number':[1,2,3,4,5],'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],
                             'Symbol':['H','He','Li','Be','B']})
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended=pd.DataFrame({'Atomic Number':[1,2,3],'Natural':'Yes'})
periodic_table_extended
# Out:
#    Atomic Number Natural
# 0              1     Yes
# 1              2     Yes
# 2              3     Yes

# %%
periodic_table.merge(periodic_table_extended,how='inner',left_on='Atomic Number',right_on='Atomic Number')
# Out:
#    Atomic Number   Element Symbol Natural
# 0              1  Hydrogen      H     Yes
# 1              2    Helium     He     Yes
# 2              3   Lithium     Li     Yes

# %%
periodic_table.merge(periodic_table_extended)
# Out:
#    Atomic Number   Element Symbol Natural
# 0              1  Hydrogen      H     Yes
# 1              2    Helium     He     Yes
# 2              3   Lithium     Li     Yes

# %%
periodic_table.merge(periodic_table_extended,how='outer',left_on='Atomic Number',right_on='Atomic Number')
# Out:
#    Atomic Number    Element Symbol Natural
# 0              1   Hydrogen      H     Yes
# 1              2     Helium     He     Yes
# 2              3    Lithium     Li     Yes
# 3              4  Beryllium     Be     NaN
# 4              5      Boron      B     NaN

# %%
periodic_table
# Out:
#    Atomic Number    Element Symbol
# 0              1   Hydrogen      H
# 1              2     Helium     He
# 2              3    Lithium     Li
# 3              4  Beryllium     Be
# 4              5      Boron      B

# %%
periodic_table_extended
# Out:
#    Atomic Number Natural
# 0              1     Yes
# 1              2     Yes
# 2              3     Yes

# %%
import pandas as pd
sales1=pd.read_csv("I:\EduBridge\Data\Sales_data1.csv")
sales1.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#          Order Date                       Purchase Address  Unnamed: 6
# 0    01/22/19 21:25        944 Walnut St, Boston, MA 02215         NaN
# 1    01/28/19 14:15       185 Maple St, Portland, OR 97035         NaN
# 2    01/17/19 13:33  538 Adams St, San Francisco, CA 94016         NaN
# 3  01-05-2019 20:33     738 10th St, Los Angeles, CA 90001         NaN
# 4    01/25/19 11:59          387 10th St, Austin, TX 73301         NaN

# %%
import pandas as pd
sales2=pd.read_csv("I:\EduBridge\Data\Sales_data2.csv")
sales2.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each Total_cost
# 0   141234                    iPhone                1        700        700
# 1   141235  Lightning Charging Cable                1      14.95      14.95
# 2   141236          Wired Headphones                2      11.99      23.98
# 3   141237          27in FHD Monitor                1     149.99     149.99
# 4   141238          Wired Headphones                1      11.99      11.99

# %%
sales1.merge(sales2,how='inner', right_on=['Order ID','Product'],left_on=['Order ID','Product'])
# Out:
#       Order ID                   Product Quantity Ordered_x Price Each_x  \
# 0       141234                    iPhone                  1          700
# 1       141235  Lightning Charging Cable                  1        14.95
# 2       141236          Wired Headphones                  2        11.99
# 3       141237          27in FHD Monitor                  1       149.99
# 4       141238          Wired Headphones                  1        11.99
# ...        ...                       ...                ...          ...
# 10628   150497              20in Monitor                  1       109.99
# 10629   150498          27in FHD Monitor                  1       149.99
# 10630   150499           ThinkPad Laptop                  1       999.99
# 10631   150500    AAA Batteries (4-pack)                  2         2.99
# 10632   150501              Google Phone                  1          600
#
#              Order Date                       Purchase Address  Unnamed: 6  \
# ...

# %%
sales1.merge(sales2,how='inner')
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 10628   150497              20in Monitor                1     109.99
# 10629   150498          27in FHD Monitor                1     149.99
# 10630   150499           ThinkPad Laptop                1     999.99
# 10631   150500    AAA Batteries (4-pack)                2       2.99
# 10632   150501              Google Phone                1        600
#
#              Order Date                       Purchase Address  Unnamed: 6  \
# ...

# %% [markdown]
# ### 6.Reshaping data:
# - Pandas provides methods for reshaping data, such as pivoting and unstacking.

# %% [markdown]
# ### Tidy data and techniques for restructuring data
# - Tidy data is a term developed by Hadley Wickham. According to a paper authored by him (Link: http://vita.had.co.nz/papers/tidy-data.pdf), these are the three principles of tidy data:
# - 1. Columns correspond to variables in the data, and each variable maps to a single column.
# - 2. The rows contain only observations, not variables.
# - 3. Each data structure or table contains only one observational unit.
# - Note that making data tidy is different from data cleansing.
# - Data cleansing is concerned with dealing with missing values and redundant information, removing filler characters, and changing inaccurate data types.
# - On the other hand, converting data to a tidy format involves restructuring the data and arranging it along the right axis, to facilitate ease of analysis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Wider

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Longer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
grades=pd.DataFrame({'Biology':[90,87,45],'Chemistry':[46,56,87],'Mathematics':[95,74,45],'Physics':[75,65,33]},index=['Andrew','Sarah','Jason'])
grades
# Out:
#         Biology  Chemistry  Mathematics  Physics
# Andrew       90         46           95       75
# Sarah        87         56           74       65
# Jason        45         87           45       33

# %%
grades_stacked=grades.stack()
grades_stacked
# Out:
# Andrew  Biology        90
#         Chemistry      46
#         Mathematics    95
#         Physics        75
# Sarah   Biology        87
#         Chemistry      56
#         Mathematics    74
#         Physics        65
# Jason   Biology        45
#         Chemistry      87
#         Mathematics    45
#         Physics        33
# dtype: int64

# %%
grades_stacked.index
# Out:
# MultiIndex([('Andrew',     'Biology'),
#             ('Andrew',   'Chemistry'),
#             ('Andrew', 'Mathematics'),
#             ('Andrew',     'Physics'),
#             ( 'Sarah',     'Biology'),
#             ( 'Sarah',   'Chemistry'),
#             ( 'Sarah', 'Mathematics'),
#             ( 'Sarah',     'Physics'),
#             ( 'Jason',     'Biology'),
#             ( 'Jason',   'Chemistry'),
#             ( 'Jason', 'Mathematics'),
#             ( 'Jason',     'Physics')],
#            )

# %%
grades_stacked=grades_stacked.reset_index()
grades_stacked
# Out:
#    level_0      level_1   0
# 0   Andrew      Biology  90
# 1   Andrew    Chemistry  46
# 2   Andrew  Mathematics  95
# 3   Andrew      Physics  75
# 4    Sarah      Biology  87
# 5    Sarah    Chemistry  56
# 6    Sarah  Mathematics  74
# 7    Sarah      Physics  65
# 8    Jason      Biology  45
# 9    Jason    Chemistry  87
# 10   Jason  Mathematics  45
# 11   Jason      Physics  33

# %%
grades_stacked.columns=['std_name','Subject','Marks']
grades_stacked
# Out:
#    std_name      Subject  Marks
# 0    Andrew      Biology     90
# 1    Andrew    Chemistry     46
# 2    Andrew  Mathematics     95
# 3    Andrew      Physics     75
# 4     Sarah      Biology     87
# 5     Sarah    Chemistry     56
# 6     Sarah  Mathematics     74
# 7     Sarah      Physics     65
# 8     Jason      Biology     45
# 9     Jason    Chemistry     87
# 10    Jason  Mathematics     45
# 11    Jason      Physics     33

# %%
grades
# Out:
#         Biology  Chemistry  Mathematics  Physics
# Andrew       90         46           95       75
# Sarah        87         56           74       65
# Jason        45         87           45       33

# %%
grades=pd.DataFrame({'Student_Name':['Andrew','Sarah','Jason'],'Biology':[90,87,45],
                     'Chemistry':[46,56,87],'Mathematics':[95,74,45],'Physics':[75,65,33]})
grades
# Out:
#   Student_Name  Biology  Chemistry  Mathematics  Physics
# 0       Andrew       90         46           95       75
# 1        Sarah       87         56           74       65
# 2        Jason       45         87           45       33

# %%
#method2
grades=grades.melt(id_vars='Student_Name',value_vars=['Biology','Chemistry','Physics','Mathematics'],
            var_name='Subject',value_name='Marks')

# %%
grades
# Out:
#    Student_Name      Subject  Marks
# 0        Andrew      Biology     90
# 1         Sarah      Biology     87
# 2         Jason      Biology     45
# 3        Andrew    Chemistry     46
# 4         Sarah    Chemistry     56
# 5         Jason    Chemistry     87
# 6        Andrew      Physics     75
# 7         Sarah      Physics     65
# 8         Jason      Physics     33
# 9        Andrew  Mathematics     95
# 10        Sarah  Mathematics     74
# 11        Jason  Mathematics     45

# %%
pd.pivot_table(grades,index='Student_Name',values='Marks',columns='Subject')
# Out:
# Subject       Biology  Chemistry  Mathematics  Physics
# Student_Name
# Andrew             90         46           95       75
# Jason              45         87           45       33
# Sarah              87         56           74       65

# %% [markdown]
# ### 7.Handling missing data:
# - Pandas provides methods for handling missing data, such as filling missing values or dropping rows or columns with missing values.

# %% [markdown]
# # Dealing with missing data
# - Missing data in Pandas is represented by the value NaN (Not a Number), denoted as the keyword np.nan.
# - We can use the isna or isnull method for finding null values.
# - Both methods return a True (for a missing value) or False (for all other values) Boolean value for each object in the Series or DataFrame.

# %%
#isna or isnull
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(data)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
covid_data.isna().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
covid_data.isnull().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
covid_data.notnull().sum() # neagtaive
# Out:
# country         206
# continent       206
# date            206
# day             206
# month           206
# year            206
# cases           206
# deaths          206
# country_code    202
# population      202
# dtype: int64

# %%
covid_data[covid_data.isna().any(axis=1)] # fillter the  NaN value contained row
# Out:
#                                        country continent        date  day  \
# 5                                     Anguilla   America  2020-04-12   12
# 24           Bonaire, Saint Eustatius and Saba   America  2020-04-12   12
# 37  Cases_on_an_international_conveyance_Japan     Other  2020-01-18   18
# 61                                     Eritrea    Africa  2020-04-12   12
# 65                 Falkland_Islands_(Malvinas)   America  2020-04-12   12
#
#     month  year  cases  deaths country_code  population
# 5       4  2020      0       0          NaN         NaN
# 24      4  2020      0       0          NaN         NaN
# 37      1  2020      0       0          NaN      3000.0
# 61      4  2020      0       0          ERI         NaN
# 65      4  2020      0       0          NaN         NaN

# %% [markdown]
# - We have two options for dealing with this missing data
# - either get rid of these values (drop them), or
# - substitute these values with a suitable measure (like the mean,median, or mode) that can be used as an approximation for the missing value.

# %% [markdown]
# ### Dropping the missing data
# - The dropna method removes all the missing values in a DataFrame or Series.

# %%
dropnadf=covid_data.dropna()

# %%
dropnadf.isna().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    0
# population      0
# dtype: int64

# %%
dropnadf[dropnadf.isna().any(axis=1)]  # No NaN value
# Out:
# Empty DataFrame
# Columns: [country, continent, date, day, month, year, cases, deaths, country_code, population]
# Index: []

# %% [markdown]
# ### Imputation
# - Imputation is the process of replacing missing values.
# - In Pandas, there is an option to substitute the missing values with measures of central tendencies like the mean, median,or mode, using the fillna method. You can also fill the missing values with a fixed or constant value like 0.
# - We can use the forward fill technique to fill the missing value with the value just before it,or the backward fill technique to substitute the null value with the value just after it.

# %% [markdown]
# ### forward fill - pad / ffill
# - Let us substitute the NaN value for the country "Anguilla" with the values preceding it (in the previous row), using the forward fill technique (ffill), as shown in the following.

# %%
covid_data.loc[4:7,:] #view some nan values
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN         NaN
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='ffill',inplace=False).loc[4:7,:]        #pad  #Fill NA/NaN values using the specified method.
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          AGO  30809762.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(method='bfill',inplace=False).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          ATG     96286.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
covid_data.fillna(0,inplace=False).loc[4:7,:]   #constant value 0
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5            0         0.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### fill with static method
# - A standard method for imputation of missing values is to substitute the null values with the mean value of the other valid observations.
# - The fillna method can be used for this purpose, as well.
# - Here, we are substituting the missing value in each column with the mean of the other two values in the column.

# %%
covid_data.mean(numeric_only=True)
# Out:
# day           1.202427e+01
# month         3.985437e+00
# year          2.020000e+03
# cases         3.952476e+02
# deaths        2.971359e+01
# population    3.731716e+07
# dtype: float64

# %%
covid_data.fillna(covid_data.mean(numeric_only=True)).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code    population
# 4          AGO  3.080976e+07
# 5          NaN  3.731716e+07
# 6          ATG  9.628600e+04
# 7          ARG  4.449450e+07

# %%
covid_data.fillna(covid_data.median(numeric_only=True)).loc[4:7,:]
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN   7042861.5
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %% [markdown]
# ### using Interpolation method
# - Interpolation is another technique for estimating missing values in numeric columns, with the most straightforward interpolation technique being the linear interpolation method.
# - In linear interpolation, the equation of a straight line is used to estimate unknown values from known values. If there are two points, (x0, y0) and (x1,y1), then an unknown point (x,y) can be estimated using the following equation:
# ![image.png](attachment:image.png)

# %%
covid_data.interpolate(method='linear').loc[4:7,:] # only applicable to numeric columns
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
#
#   country_code  population
# 4          AGO  30809762.0
# 5          NaN  15453024.0
# 6          ATG     96286.0
# 7          ARG  44494502.0

# %%
https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %% [markdown]
# ### 8.Transforming data:
# - Pandas provides methods for transforming data, such as applying functions or scaling values.

# %%
import pandas as pd 
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv"
olympics=pd.read_csv(url,skiprows=4)
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.Gender.unique() #Return unique values of Series object.
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
def convert_gender(value):
    if value == 'Men':
        return 0
    elif value == 'Women':
        return 1

# %%
olympics['Gender']=olympics['Gender'].apply(convert_gender)

# %%
olympics['Gender1']=olympics['Gender'].map({'Men': 0, 'Women': 1})

# %%
olympics.Gender1.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  Gender1
# 0              100m freestyle            M    Gold        0
# 1              100m freestyle            M  Silver        0
# 2  100m freestyle for sailors            M  Bronze        0
# 3  100m freestyle for sailors            M    Gold        0
# 4  100m freestyle for sailors            M  Silver        0

# %%
olympics.Gender.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
olympics['f_name']=olympics.Athlete.apply(lambda x:x.split(',')[0])

# %% [markdown]
# olympics.Athlete.str.split(',')

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  Gender1      f_name
# 0              100m freestyle            M    Gold        0       HAJOS
# 1              100m freestyle            M  Silver        0  HERSCHMANN
# 2  100m freestyle for sailors            M  Bronze        0      DRIVAS
# 3  100m freestyle for sailors            M    Gold        0   MALOKINIS
# 4  100m freestyle for sailors            M  Silver        0    CHASAPIS

# %%
Example2:

# %%
#isna or isnull
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
def diffrence(row):
    return row['cases']-row['deaths']

# %%
covid_data['diffrence']=covid_data.apply(diffrence,axis=1) #covid_data['cases']-covid_data['deaths']

# %%
covid_data['diffrence2']=covid_data.apply(lambda df:df['cases']-df['deaths'],axis=1)

# %%
covid_data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population  diffrence  diffrence2  en_continent
# 0          AFG  37172386.0         31          31             0
# 1          ALB   2866376.0         17          17             1
# 2          DZA  42228429.0         45          45             2
# 3          AND     77006.0         19          19             1
# 4          AGO  30809762.0          0           0             2

# %%
covid_data.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'America', 'Oceania', 'Other'],
#       dtype=object)

# %%
covid_data['en_continent']=covid_data.continent.map({'Asia':0, 'Europe':1, 'Africa':2, 'America':3, 'Oceania':4, 'Other':5})

# %%
covid_data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population  diffrence  diffrence2  en_continent
# 0          AFG  37172386.0         31          31             0
# 1          ALB   2866376.0         17          17             1
# 2          DZA  42228429.0         45          45             2
# 3          AND     77006.0         19          19             1
# 4          AGO  30809762.0          0           0             2

# %% [markdown]
# ### 9.Calculating statistics:
# - Pandas provides methods for calculating various statistics, such as mean, median, standard deviation, and more.

# %%
import numpy as np
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/subset-covid-data.csv"
covid_data=pd.read_csv(url)
covid_data.head(3)
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0

# %%
# avg caeses 
covid_data.cases.mean()
# Out:
# 395.247572815534

# %%
covid_data.cases.median()
# Out:
# 11.5

# %%
# decscriptive statistics
covid_data.describe()
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 25%     12.000000    4.000000  2020.0      0.000000     0.000000  1.278222e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 75%     12.000000    4.000000  2020.0     88.750000     3.000000  2.600084e+07
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %%
covid_data.describe(include='all')
# Out:
#             country continent        date         day       month    year  \
# count           206       206         206  206.000000  206.000000   206.0
# unique          206         6           3         NaN         NaN     NaN
# top     Afghanistan    Europe  2020-04-12         NaN         NaN     NaN
# freq              1        54         204         NaN         NaN     NaN
# mean            NaN       NaN         NaN   12.024272    3.985437  2020.0
# std             NaN       NaN         NaN    0.424141    0.209020     0.0
# min             NaN       NaN         NaN   11.000000    1.000000  2020.0
# 25%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# 50%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# 75%             NaN       NaN         NaN   12.000000    4.000000  2020.0
# max             NaN       NaN         NaN   18.000000    4.000000  2020.0
#
#                cases       deaths country_code    population
# ...

# %%
covid_data.std(numeric_only=True)
# Out:
# day           4.241413e-01
# month         2.090199e-01
# year          2.279276e-13
# cases         2.160176e+03
# deaths        1.595331e+02
# population    1.413776e+08
# dtype: float64

# %%
covid_data.var(numeric_only=True)
# Out:
# day           1.798958e-01
# month         4.368932e-02
# year          5.195098e-26
# cases         4.666362e+06
# deaths        2.545082e+04
# population    1.998762e+16
# dtype: float64

# %%
covid_data.corr()
# Out:
#                  day     month  year     cases    deaths  population
# day         1.000000 -0.986416   NaN -0.034746 -0.054326   -0.019167
# month      -0.986416  1.000000   NaN  0.012810  0.013040    0.018663
# year             NaN       NaN   NaN       NaN       NaN         NaN
# cases      -0.034746  0.012810   NaN  1.000000  0.943220    0.175539
# deaths     -0.054326  0.013040   NaN  0.943220  1.000000    0.145211
# population -0.019167  0.018663   NaN  0.175539  0.145211    1.000000

# %%
covid_data.cases.mean()
# Out:
# 395.247572815534

# %%
covid_data.std()
# Out:
# 2160.1764385637084

# %%
#Normalization

# %%
covid_data['Norm_cases']=covid_data.cases.apply(lambda x:(x-395.247572815534)/2160.1764385637084)

# %%
covid_data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population  Norm_cases
# 0          AFG  37172386.0   -0.167231
# 1          ALB   2866376.0   -0.175100
# 2          DZA  42228429.0   -0.153343
# 3          AND     77006.0   -0.173249
# 4          AGO  30809762.0   -0.182970

# %%
covid_data.Norm_cases.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
covid_data.cases.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
covid_data.skew(numeric_only=True)
# Out:
# day           13.706469
# month        -14.352700
# year           0.000000
# cases         11.147011
# deaths         8.512769
# population     8.566707
# dtype: float64

# %%
covid_data.population.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
covid_data.describe(percentiles=[.3,.6,.9,.95])
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 30%     12.000000    4.000000  2020.0      1.000000     0.000000  2.093853e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 60%     12.000000    4.000000  2020.0     28.000000     1.000000  1.115450e+07
# 90%     12.000000    4.000000  2020.0    446.000000    20.500000  6.693742e+07
# 95%     12.000000    4.000000  2020.0   1342.250000    80.000000  1.253425e+08
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %%
covid_data.describe(include='object')
# Out:
#             country continent        date country_code
# count           206       206         206          202
# unique          206         6           3          202
# top     Afghanistan    Europe  2020-04-12          AFG
# freq              1        54         204            1

# %%
covid_data.describe(include='number')
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 25%     12.000000    4.000000  2020.0      0.000000     0.000000  1.278222e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 75%     12.000000    4.000000  2020.0     88.750000     3.000000  2.600084e+07
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %% [markdown]
# ### 10.Plotting data:
# - Pandas provides methods for creating plots and charts to visualize data.

# %%
# finding Missing Values:
file="I:\EduBridge\Data\Divvy_Trips_2020_Q1\Divvy_Trips_2020_Q1.csv"
Trips_2020=pd.read_csv(file)
Trips_2020.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  EACB19130B0CDA4A   docked_bike  2020-01-21 20:06:59  2020-01-21 20:14:30
# 1  8FED874C809DC021   docked_bike  2020-01-30 14:22:39  2020-01-30 14:26:22
# 2  789F3C21E472CA96   docked_bike  2020-01-09 19:29:26  2020-01-09 19:32:17
# 3  C9A388DAC6ABF313   docked_bike  2020-01-06 16:17:07  2020-01-06 16:25:56
# 4  943BC3CBECCFD662   docked_bike  2020-01-30 08:37:16  2020-01-30 08:42:48
#
#          start_station_name  start_station_id                end_station_name  \
# 0  Western Ave & Leland Ave               239           Clark St & Leland Ave
# 1   Clark St & Montrose Ave               234  Southport Ave & Irving Park Rd
# 2    Broadway & Belmont Ave               296        Wilton Ave & Belmont Ave
# 3    Clark St & Randolph St                51        Fairbanks Ct & Grand Ave
# 4      Clinton St & Lake St                66           Wells St & Hubbard St
#
# ...

# %%
Trips_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426887 entries, 0 to 426886
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             426887 non-null  object
#  1   rideable_type       426887 non-null  object
#  2   started_at          426887 non-null  object
#  3   ended_at            426887 non-null  object
#  4   start_station_name  426887 non-null  object
#  5   start_station_id    426887 non-null  int64
#  6   end_station_name    426886 non-null  object
#  7   end_station_id      426886 non-null  float64
#  8   start_lat           426887 non-null  float64
#  9   start_lng           426887 non-null  float64
#  10  end_lat             426886 non-null  float64
#  11  end_lng             426886 non-null  float64
#  12  member_casual       426887 non-null  object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 42.3+ MB

# %%
# find Missing Values from Dataframe
Trips_2020.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      1
# end_station_id        1
# start_lat             0
# start_lng             0
# end_lat               1
# end_lng               1
# member_casual         0
# dtype: int64

# %%
Trips_2020[Trips_2020.end_station_id.isna()]
# Out:
#                  ride_id rideable_type           started_at  \
# 414426  157EAA4C4A3C8D36   docked_bike  2020-03-16 11:23:36
#
#                    ended_at start_station_name  start_station_id  \
# 414426  2020-03-16 11:23:24              HQ QR               675
#
#        end_station_name  end_station_id  start_lat  start_lng  end_lat  \
# 414426              NaN             NaN    41.8899   -87.6803      NaN
#
#         end_lng member_casual
# 414426      NaN        casual

# %%
Trips_2020.loc[414426:414435,:]
# Out:
#                  ride_id rideable_type           started_at  \
# 414426  157EAA4C4A3C8D36   docked_bike  2020-03-16 11:23:36
# 414427  23082422605E66EE   docked_bike  2020-03-16 11:24:23
# 414428  1CB8C992EB6AE18B   docked_bike  2020-03-16 11:24:02
# 414429  5F425649F57E5B90   docked_bike  2020-03-10 13:16:13
# 414430  81E67ACDF50E8D8F   docked_bike  2020-03-10 13:16:36
# 414431  104361E0A2560AC2   docked_bike  2020-03-01 13:48:24
# 414432  013214F7BE4C7735   docked_bike  2020-03-10 17:51:11
# 414433  9A4D7BB2B363C961   docked_bike  2020-03-05 16:16:40
# 414434  FFF00D6F72A85687   docked_bike  2020-03-05 06:56:55
# 414435  7E15CEA3C715CC2B   docked_bike  2020-03-22 11:41:31
#
#                    ended_at         start_station_name  start_station_id  \
# 414426  2020-03-16 11:23:24                      HQ QR               675
# 414427  2020-03-16 11:24:25                      HQ QR               675
# 414428  2020-03-16 11:24:03                      HQ QR               675
# ...

# %%
Trips_2020.fillna(100,inplace=True)

# %%
#remove Nan value/ missing Values from Dataframe using dropna()
Trips_2020.dropna(inplace=True)

# %% [markdown]
# # statistics   - 12.01.2023

# %%
Mean:

# %% [markdown]
# Harmonic Mean:
#     ![image.png](attachment:image.png)

# %%
x=[15,18,23,25,30]
hm=len(x)/sum(1/xi for xi in x)
print(hm)
# Out:
# 20.917542441390463

# %%
1/15
# Out:
# 0.06666666666666667

# %%
[1/xi for xi in x]
# Out:
# [0.06666666666666667,
#  0.05555555555555555,
#  0.043478260869565216,
#  0.04,
#  0.03333333333333333]

# %%
import statistics
statistics.harmonic_mean(x)#Return the harmonic mean of data.
# Out:
# 20.917542441390463

# %%
Median

# %%
import numpy as np

# %%
l1=[10, 36, 85, 66, 86, 77, 21, 26, 19, 34]
l1.sort()
l1
# Out:
# [10, 19, 21, 26, 34, 36, 66, 77, 85, 86]

# %%
(34+36)/2
# Out:
# 35.0

# %%
#even  m,m+1/2

# %%
arr2=np.array([10, 36, 85, 66, 86, 77, 21, 26, 19, 34])
np.median(arr2)
# Out:
# 35.0

# %%
#odd m

# %%
arr3=np.array([10, 36, 85, 66,77, 21, 26, 19, 34])
np.median(arr3)
# Out:
# 34.0

# %%
statistics.median([-2000, 36, 85, 66,77,21, 26, 19, 30000000])
# Out:
# 36

# %%
l2=[-2000, 36, 85, 66,77,21, 26, 19, 30000000]
l2.sort()
l2
# Out:
# [-2000, 19, 21, 26, 36, 66, 77, 85, 30000000]

# %%
mean
sum([-2000, 36, 85, 66,77,21, 26, 19, 30000000])/len([-2000, 36, 85, 66,77,21, 26, 19, 30000000])
# Out:
# 3333147.777777778

# %%
data1=[3,4,4,4,5,6,7,7,7,8,9,10]
statistics.mode(data1)
# Out:
# 4

# %%
data=[3,4,4,4,4,5,6,7,7,7,7,8,8,8,8,9,10]
statistics.multimode(data)
# Out:
# [4, 7, 8]

# %%
data= [2393, 5403,2140,9195,4132,9429,8054,3150,5447,5483] 
statistics.variance(data) #Return the sample variance of data.
# Out:
# 7106603.822222223

# %%
statistics.pvariance(data) #Return the population variance of ``data``.
# Out:
# 6395943.44

# %%
statistics.pstdev(data) #Return the square root of the population variance.
# Out:
# 2529.0202529833564

# %%
statistics.stdev(data) #Return the square root of the sample variance.
# Out:
# 2665.821416040884

# %%
Usuing Numpy

# %%
np.var(data)
# Out:
# 6395943.4399999995

# %%
np.var(data,ddof=1) # sample Variance #"Delta Degrees of Freedom
# Out:
# 7106603.822222222

# %%
np.std(data) #population Std #Compute the standard deviation along the specified axis
# Out:
# 2529.0202529833564

# %%
np.std(data,ddof=1)# sample stdev
# Out:
# 2665.8214160408834

# %%
print(dir(statistics))
# Out:
# ['Counter', 'Decimal', 'Fraction', 'NormalDist', 'StatisticsError', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_coerce', '_convert', '_exact_ratio', '_fail_neg', '_find_lteq', '_find_rteq', '_isfinite', '_normal_dist_inv_cdf', '_ss', '_sum', 'bisect_left', 'bisect_right', 'erf', 'exp', 'fabs', 'fmean', 'fsum', 'geometric_mean', 'groupby', 'harmonic_mean', 'hypot', 'itemgetter', 'log', 'math', 'mean', 'median', 'median_grouped', 'median_high', 'median_low', 'mode', 'multimode', 'numbers', 'pstdev', 'pvariance', 'quantiles', 'random', 'sqrt', 'stdev', 'tau', 'variance']
